# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialize random number generator
np.random.seed(123)

# True parameter values
alpha, sigma = 1, 1
beta = [1, 2.5]

# Size of dataset
size = 100

# Predictor variable
X1 = np.random.randn(size)
X2 = np.random.randn(size) * 0.2

# Simulate outcome variable
Y = alpha + beta[0]*X1 + beta[1]*X2 + np.random.randn(size)*sigma

# %%
# %matplotlib inline

fig, axes = plt.subplots(1, 2, sharex=True, figsize=(10,4))
axes[0].scatter(X1, Y)
axes[1].scatter(X2, Y)
axes[0].set_ylabel('Y'); axes[0].set_xlabel('X1'); axes[1].set_xlabel('X2');

# %%
try:
    from pandas_datareader import data
except ImportError:
    # !pip install pandas-datareader
    from pandas_datareader import data

# %%
import pandas as pd

returns = data.get_data_yahoo('SPY', start='2008-5-1', end='2009-12-1')['Adj Close'].pct_change()

print(len(returns))
# Out:
# 401

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

returns.plot(figsize=(10, 6))
plt.ylabel('daily returns in %');

# %%
import numpy as np

from pymc3 import traceplot

fig, ax = plt.subplots(figsize=(15, 8))
returns.plot(ax=ax)
ax.plot(returns.index, 1/np.exp(trace['s',::5].T), 'r', alpha=.03);
ax.set(title='volatility_process', xlabel='time', ylabel='volatility');
ax.legend(['S&P500', 'stochastic volatility process'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7102cc8d4586> in <module>()
#       5 fig, ax = plt.subplots(figsize=(15, 8))
#       6 returns.plot(ax=ax)
# ----> 7 ax.plot(returns.index, 1/np.exp(trace['s',::5].T), 'r', alpha=.03);
#       8 ax.set(title='volatility_process', xlabel='time', ylabel='volatility');
#       9 ax.legend(['S&P500', 'stochastic volatility process'])
#
# NameError: name 'trace' is not defined
